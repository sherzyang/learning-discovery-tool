# %% [markdown]
# ## Load Files and Vectorize

# %%
import os
import numpy as np
import pandas as pd
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine, cdist

# %%
with open(r"data/df_corpus2.pkl", "rb") as input_file:
    df_corpus2 = pickle.load(input_file)

# %%
df_corpus2.head()
# Out:
#                                              content  score
# 0  Nature Reviews Nephrology (before 2009, Nature...   20.6
# 1  Food blogging represents a complex interweavin...   13.6
# 2  The International Motorcycle Shows are a serie...   13.3
# 3  Education in Ancient Greece was vastly "democr...   11.3
# 4  Rural economics is the study of rural economie...   12.5

# %% [markdown]
# ## Data Preprocessing

# %%
! pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/b4/fb/c0cefcecf82b445ff2a714935db5b475a25202d6b63241c7e95ca004136a/gensim-3.7.3-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (24.7MB)
#      |████████████████████████████████| 24.7MB 1.1MB/s eta 0:00:01    |██▌                             | 1.9MB 1.1MB/s eta 0:00:22
# Collecting smart-open>=1.7.0 (from gensim)
#   Using cached https://files.pythonhosted.org/packages/37/c0/25d19badc495428dec6a4bf7782de617ee0246a9211af75b302a2681dea7/smart_open-1.8.4.tar.gz
# Requirement already satisfied: scipy>=0.18.1 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from gensim) (1.2.1)
# Requirement already satisfied: six>=1.5.0 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: numpy>=1.11.3 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from gensim) (1.16.4)
# Requirement already satisfied: boto>=2.32 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from smart-open>=1.7.0->gensim) (2.49.0)
# Requirement already satisfied: requests in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from smart-open>=1.7.0->gensim) (2.22.0)
# Collecting boto3 (from smart-open>=1.7.0->gensim)
#   Downloading https://files.pythonhosted.org/packages/f8/b2/af1c6efe6fc0242a7acbc69e50e592d25c5d5c18e05dd9afaf69e9317dc9/boto3-1.9.181-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 954kB/s eta 0:00:01
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.7.0->gensim) (1.24.2)
# Collecting s3transfer<0.3.0,>=0.2.0 (from boto3->smart-open>=1.7.0->gensim)
#   Using cached https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl
# Collecting botocore<1.13.0,>=1.12.181 (from boto3->smart-open>=1.7.0->gensim)
#   Downloading https://files.pythonhosted.org/packages/38/78/46586b9677bfc467ed5140c409c918ad7b025fb4bb83f2d5074da5872257/botocore-1.12.181-py2.py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 1.0MB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.7.0->gensim)
#   Using cached https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Requirement already satisfied: docutils>=0.10 in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.181->boto3->smart-open>=1.7.0->gensim) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /Users/sherzyang/anaconda3/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.181->boto3->smart-open>=1.7.0->gensim) (2.8.0)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py) ... done
#   Stored in directory: /Users/sherzyang/Library/Caches/pip/wheels/5f/ea/fb/5b1a947b369724063b2617011f1540c44eb00e28c3d2ca8692
# Successfully built smart-open
# Installing collected packages: jmespath, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto3-1.9.181 botocore-1.12.181 gensim-3.7.3 jmespath-0.9.4 s3transfer-0.2.1 smart-open-1.8.4

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sherzyang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
processed_docs = df_corpus2['content'].map(preprocess)
#processed_docs[:10]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 adult
# 1 apply
# 2 cancer
# 3 child
# 4 chronic
# 5 citation
# 6 clinical
# 7 coverage
# 8 diagnosis
# 9 dialysis
# 10 disorder

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.11463756621225898),
#  (1, 0.05765586532617539),
#  (2, 0.13892712182502004),
#  (3, 0.09102312571345948),
#  (4, 0.1579255683226295),
#  (5, 0.15342950456468332),
#  (6, 0.12687624510705903),
#  (7, 0.13979034449587607),
#  (8, 0.15698604788106313),
#  (9, 0.11687015539050881),
#  (10, 0.19033509306520321),
#  (11, 0.0714941413459945),
#  (12, 0.10949456875642996),
#  (13, 0.15330801836500396),
#  (14, 0.2324912851948214),
#  (15, 0.2429152820827657),
#  (16, 0.07326354021919622),
#  (17, 0.10778082117698098),
#  (18, 0.1918594902864103),
#  (19, 0.24513212262921247),
#  (20, 0.13877712452498228),
#  (21, 0.20848419321557235),
#  (22, 0.09049542779379403),
#  (23, 0.27958124452493754),
#  (24, 0.18772634012563447),
#  (25, 0.10850653149179024),
#  (26, 0.16206489016436754),
#  (27, 0.05663309758786264),
#  (28, 0.1465052227617137),
#  (29, 0.05518954915829813),
#  (30, 0.2653244279611047),
#  (31, 0.11564191336679187),
#  (32, 0.2139591889419809),
#  (33, 0.32931380435014446),
#  (34, 0.17846492643608908),
#  (35, 0.09913014119814909)]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.008*"century" + 0.007*"literature" + 0.006*"write" + 0.004*"book" + 0.004*"bear" + 0.004*"ancient" + 0.004*"roman" + 0.004*"museum" + 0.003*"form" + 0.003*"period"
# Topic: 1
# Words: 0.007*"self" + 0.007*"music" + 0.006*"people" + 0.006*"culture" + 0.005*"health" + 0.004*"psychology" + 0.004*"group" + 0.003*"study" + 0.003*"social" + 0.003*"form"
# Topic: 2
# Words: 0.007*"social" + 0.006*"study" + 0.005*"theory" + 0.005*"science" + 0.004*"human" + 0.004*"philosophy" + 0.004*"research" + 0.004*"self" + 0.003*"society" + 0.003*"university"
# Topic: 3
# Words: 0.006*"film" + 0.006*"series" + 0.005*"star" + 0.004*"american" + 0.004*"television" + 0.004*"music" + 0.004*"award" + 0.003*"release" + 0.003*"show" + 0.003*"season"
# Topic: 4
# Words: 0.009*"university" + 0.007*"program" + 0.007*"engineer" + 0.006*"school" + 0.006*"technology" + 0.006*"science" + 0.005*"education" + 0.005*"college" + 0.005*"research" + 0.004*"institute"
# Topic: 5
# Words: 0.009*"food" + 0.007*"company" + 0.005*"market" + 0.004*"drink" + 0.004*"finance" + 0.004*"service" + 0.003*"unite" + 0.003*"world" + 0.003*"financial" + 0.003*"bank"
# Topic: 6
# Words: 0.004*"government" + 0.004*"unite" + 0.004*"century" + 0.004*"world" + 0.004*"people" + 0.003*"city" + 0.003*"economic" + 0.003*"south" + 0.003*"empire" + 0.003*"force"
# Topic: 7
# Words: 0.019*"language" + 0.017*"film" + 0.007*"languages" + 0.005*"write" + 0.005*"word" + 0.005*"speak" + 0.004*"form" + 0.004*"english" + 0.003*"century" + 0.003*"people"
# Topic: 8
# Words: 0.008*"road" + 0.007*"county" + 0.007*"city" + 0.005*"highway" + 0.005*"north" + 0.004*"miles" + 0.004*"line" + 0.004*"south" + 0.004*"route" + 0.003*"east"
# Topic: 9
# Words: 0.014*"music" + 0.006*"displaystyle" + 0.005*"number" + 0.004*"record" + 0.003*"group" + 0.003*"release" + 0.003*"rock" + 0.003*"begin" + 0.003*"space" + 0.003*"album"

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.002*"film" + 0.001*"language" + 0.001*"actors" + 0.001*"nepal" + 0.001*"list" + 0.001*"drink" + 0.001*"movies" + 0.001*"bear" + 0.001*"music" + 0.001*"hindi"
# Topic: 1 Word: 0.003*"music" + 0.002*"finance" + 0.002*"university" + 0.001*"journal" + 0.001*"engineer" + 0.001*"sciences" + 0.001*"global" + 0.001*"program" + 0.001*"science" + 0.001*"technology"
# Topic: 2 Word: 0.002*"self" + 0.002*"social" + 0.002*"behavior" + 0.002*"theory" + 0.002*"psychology" + 0.002*"economics" + 0.002*"displaystyle" + 0.001*"model" + 0.001*"market" + 0.001*"study"
# Topic: 3 Word: 0.001*"music" + 0.001*"food" + 0.001*"social" + 0.001*"museum" + 0.001*"science" + 0.001*"cities" + 0.001*"university" + 0.001*"anthropology" + 0.001*"album" + 0.001*"sciences"
# Topic: 4 Word: 0.003*"journal" + 0.002*"transportation" + 0.002*"environment" + 0.002*"psychology" + 0.002*"science" + 0.002*"department" + 0.002*"index" + 0.002*"finance" + 0.002*"philosophy" + 0.001*"nature"
# Topic: 5 Word: 0.005*"music" + 0.004*"film" + 0.003*"album" + 0.003*"award" + 0.002*"actor" + 0.002*"actors" + 0.002*"finance" + 0.002*"release" + 0.002*"song" + 0.002*"band"
# Topic: 6 Word: 0.001*"finance" + 0.001*"cities" + 0.001*"science" + 0.001*"university" + 0.001*"language" + 0.001*"list" + 0.001*"engineer" + 0.001*"global" + 0.001*"century" + 0.001*"city"
# Topic: 7 Word: 0.002*"museum" + 0.002*"cities" + 0.002*"century" + 0.002*"city" + 0.001*"ancient" + 0.001*"anthropology" + 0.001*"university" + 0.001*"culture" + 0.001*"population" + 0.001*"south"
# Topic: 8 Word: 0.004*"film" + 0.003*"language" + 0.002*"music" + 0.002*"drink" + 0.002*"movies" + 0.002*"channel" + 0.002*"television" + 0.002*"company" + 0.002*"game" + 0.002*"languages"
# Topic: 9 Word: 0.002*"food" + 0.002*"university" + 0.002*"engineer" + 0.002*"science" + 0.002*"literature" + 0.002*"sciences" + 0.001*"anthropology" + 0.001*"economics" + 0.001*"technology" + 0.001*"ministry"

# %%
processed_docs[4310]
# Out:
# ['society',
#  'group',
#  'individuals',
#  'involve',
#  'persistent',
#  'social',
#  'interaction',
#  'large',
#  'social',
#  'group',
#  'share',
#  'geographical',
#  'social',
#  'territory',
#  'typically',
#  'subject',
#  'political',
#  'authority',
#  'dominant',
#  'cultural',
#  'expectations',
#  'societies',
#  'characterize',
#  'pattern',
#  'relationships',
#  'social',
#  'relations',
#  'individuals',
#  'share',
#  'distinctive',
#  'culture',
#  'institutions',
#  'give',
#  'society',
#  'describe',
#  'total',
#  'relationships',
#  'constituent',
#  'members',
#  'social',
#  'sciences',
#  'larger',
#  'society',
#  'exhibit',
#  'stratification',
#  'dominance',
#  'pattern',
#  'subgroups',
#  'insofar',
#  'collaborative',
#  'society',
#  'enable',
#  'members',
#  'benefit',
#  'ways',
#  'possible',
#  'individual',
#  'basis',
#  'individual',
#  'social',
#  'common',
#  'benefit',
#  'distinguish',
#  'case',
#  'overlap',
#  'society',
#  'consist',
#  'like',
#  'mind',
#  'people',
#  'govern',
#  'norms',
#  'value',
#  'dominant',
#  'larger',
#  'society',
#  'refer',
#  'subculture',
#  'term',
#  'extensively',
#  'criminology',
#  'broadly',
#  'especially',
#  'structuralist',
#  'think',
#  'society',
#  'illustrate',
#  'economic',
#  'social',
#  'industrial',
#  'cultural',
#  'infrastructure',
#  'distinct',
#  'vary',
#  'collection',
#  'individuals',
#  'regard',
#  'society',
#  'mean',
#  'objective',
#  'relationships',
#  'people',
#  'material',
#  'world',
#  'people',
#  'people',
#  'individual',
#  'familiar',
#  'social',
#  'environment',
#  'etymology',
#  'usage',
#  'term',
#  'society',
#  'come',
#  'latin',
#  'word',
#  'societas',
#  'turn',
#  'derive',
#  'noun',
#  'socius',
#  'comrade',
#  'friend',
#  'ally',
#  'adjectival',
#  'form',
#  'socialis',
#  'bond',
#  'interaction',
#  'party',
#  'friendly',
#  'civil',
#  'article',
#  'term',
#  'refer',
#  'entirety',
#  'humanity',
#  'society',
#  'general',
#  'society',
#  'large',
#  'unfriendly',
#  'uncivil',
#  'remainder',
#  'society',
#  'sense',
#  'deem',
#  'antisocial',
#  'scottish',
#  'economist',
#  'adam',
#  'smith',
#  'teach',
#  'instead',
#  'society',
#  'subsist',
#  'different',
#  'different',
#  'merchants',
#  'sense',
#  'utility',
#  'mutual',
#  'love',
#  'affection',
#  'refrain',
#  'injury',
#  'sense',
#  'association',
#  'society',
#  'body',
#  'individuals',
#  'outline',
#  'bound',
#  'functional',
#  'interdependence',
#  'possibly',
#  'comprise',
#  'characteristics',
#  'national',
#  'cultural',
#  'identity',
#  'social',
#  'solidarity',
#  'language',
#  'hierarchical',
#  'structure',
#  'conceptions',
#  'society',
#  'general',
#  'address',
#  'fact',
#  'individual',
#  'limit',
#  'mean',
#  'autonomous',
#  'unit',
#  'great',
#  'ape',
#  'bonobo',
#  'homo',
#  'gorilla',
#  'pongo',
#  'social',
#  'animals',
#  'robinson',
#  'crusoe',
#  'like',
#  'situations',
#  'fictions',
#  'unusual',
#  'corner',
#  'case',
#  'ubiquity',
#  'social',
#  'context',
#  'humans',
#  'fall',
#  'presocial',
#  'eusocial',
#  'spectrum',
#  'animal',
#  'ethology',
#  'cultural',
#  'relativism',
#  'widespread',
#  'approach',
#  'ethic',
#  'largely',
#  'replace',
#  'notions',
#  'primitive',
#  'better',
#  'worse',
#  'progress',
#  'relation',
#  'culture',
#  'include',
#  'material',
#  'culture',
#  'technology',
#  'social',
#  'organization',
#  'accord',
#  'anthropologist',
#  'maurice',
#  'godelier',
#  'critical',
#  'novelty',
#  'society',
#  'contrast',
#  'humanity',
#  'closest',
#  'biological',
#  'relatives',
#  'chimpanzees',
#  'bonobos',
#  'parental',
#  'role',
#  'assume',
#  'males',
#  'supposedly',
#  'absent',
#  'nearest',
#  'relatives',
#  'paternity',
#  'generally',
#  'determinable',
#  'political',
#  'science',
#  'societies',
#  'structure',
#  'politically',
#  'order',
#  'increase',
#  'size',
#  'complexity',
#  'band',
#  'tribes',
#  'chiefdoms',
#  'state',
#  'societies',
#  'structure',
#  'vary',
#  'degrees',
#  'political',
#  'power',
#  'depend',
#  'cultural',
#  'geographical',
#  'historical',
#  'environments',
#  'societies',
#  'contend',
#  'isolate',
#  'society',
#  'level',
#  'technology',
#  'culture',
#  'societies',
#  'likely',
#  'survive',
#  'close',
#  'proximity',
#  'encroach',
#  'resources',
#  'society',
#  'unable',
#  'offer',
#  'effective',
#  'response',
#  'societies',
#  'compete',
#  'usually',
#  'subsume',
#  'culture',
#  'compete',
#  'society',
#  'sociology',
#  'sociologist',
#  'peter',
#  'berger',
#  'define',
#  'society',
#  'human',
#  'product',
#  'human',
#  'product',
#  'continuously',
#  'act',
#  'producers',
#  'accord',
#  'society',
#  'create',
#  'humans',
#  'creation',
#  'turn',
#  'create',
#  'mold',
#  'humans',
#  'sociologist',
#  'gerhard',
#  'lenski',
#  'differentiate',
#  'societies',
#  'base',
#  'level',
#  'technology',
#  'communication',
#  'economy',
#  'hunters',
#  'gatherers',
#  'simple',
#  'agricultural',
#  'advance',
#  'agricultural',
#  'industrial',
#  'special',
#  'fish',
#  'societies',
#  'maritime',
#  'societies',
#  'similar',
#  'earlier',
#  'develop',
#  'anthropologists',
#  'morton',
#  'fry',
#  'conflict',
#  'theorist',
#  'elman',
#  'service',
#  'integration',
#  'theorist',
#  'produce',
#  'classification',
#  'societies',
#  'human',
#  'culture',
#  'base',
#  'evolution',
#  'social',
#  'inequality',
#  'role',
#  'state',
#  'classification',
#  'contain',
#  'categories',
#  'hunter',
#  'gatherer',
#  'band',
#  'categorization',
#  'duties',
#  'tribal',
#  'societies',
#  'limit',
#  'instance',
#  'social',
#  'rank',
#  'prestige',
#  'stratify',
#  'structure',
#  'chieftains',
#  'civilizations',
#  'complex',
#  'social',
#  'hierarchies',
#  'organize',
#  'institutional',
#  'governments',
#  'addition',
#  'humanity',
#  'humankind',
#  'rest',
#  'elements',
#  'society',
#  'include',
#  'society',
#  'beliefs',
#  'virtual',
#  'society',
#  'society',
#  'base',
#  'online',
#  'identity',
#  'evolve',
#  'information',
#  'time',
#  'culture',
#  'progress',
#  'complex',
#  'form',
#  'organization',
#  'control',
#  'cultural',
#  'evolution',
#  'profound',
#  'effect',
#  'pattern',
#  'community',
#  'hunter',
#  'gatherer',
#  'tribes',
#  'settle',
#  'seasonal',
#  'food',
#  'stock',
#  'agrarian',
#  'villages',
#  'villages',
#  'grow',
#  'towns',
#  'cities',
#  'cities',
#  'turn',
#  'city',
#  'state',
#  'nation',
#  'state',
#  'societies',
#  'distribute',
#  'largess',
#  'behest',
#  'individual',
#  'larger',
#  'group',
#  'people',
#  'type',
#  'generosity',
#  'see',
#  'know',
#  'culture',
#  'typically',
#  'prestige',
#  'accrue',
#  'generous',
#  'individual',
#  'group',
#  'conversely',
#  'members',
#  'society',
#  'shun',
#  'scapegoat',
#  'members',
#  'society',
#  'violate',
#  'norms',
#  'mechanisms',
#  'gift',
#  'give',
#  'joke',
#  'relationships',
#  'scapegoating',
#  'see',
#  'type',
#  'human',
#  'group',
#  'tend',
#  'society',
#  'social',
#  'evolution',
#  'phenomenon',
#  'carry',
#  'certain',
#  'elements',
#  'detrimental',
#  'population',
#  'serve',
#  'societies',
#  'bestow',
#  'status',
#  'individual',
#  'group',
#  'people',
#  'individual',
#  'group',
#  'perform',
#  'admire',
#  'desire',
#  'action',
#  'type',
#  'recognition',
#  'bestow',
#  'form',
#  'title',
#  'manner',
#  'dress',
#  'monetary',
#  'reward',
#  'societies',
#  'adult',
#  'male',
#  'female',
#  'status',
#  'subject',
#  'ritual',
#  'process',
#  'type',
#  'altruistic',
#  'action',
#  'interest',
#  'larger',
#  'group',
#  'see',
#  'virtually',
#  'societies',
#  'phenomena',
#  'community',
#  'action',
#  'shun',
#  'scapegoating',
#  'generosity',
#  'share',
#  'risk',
#  'reward',
#  'common',
#  'form',
#  'society',
#  'type',
#  'societies',
#  'social',
#  'group',
#  'differ',
#  'accord',
#  'subsistence',
#  'strategies',
#  'ways',
#  'humans',
#  'technology',
#  'provide',
#  'need',
#  'humans',
#  'establish',
#  'type',
#  'societies',
#  'history',
#  'anthropologists',
#  'tend',
#  'classify',
#  'different',
#  'societies',
#  'accord',
#  'degree',
#  'different',
#  'group',
#  'society',
#  'unequal',
#  'access',
#  'advantage',
#  'resources',
#  'prestige',
#  'power',
#  'virtually',
#  'societies',
#  'develop',
#  'degree',
#  'inequality',
#  'people',
#  'process',
#  'social',
#  'stratification',
#  'division',
#  'members',
#  'society',
#  'level',
#  'unequal',
#  'wealth',
#  'prestige',
#  'power',
#  'sociologists',
#  'place',
#  'societies',
#  'broad',
#  'categories',
#  'industrial',
#  'industrial',
#  'postindustrial',
#  'industrial',
#  'industrial',
#  'society',
#  'food',
#  'production',
#  'carry',
#  'human',
#  'animal',
#  'labor',
#  'main',
#  'economic',
#  'activity',
#  'societies',
#  'subdivide',
#  'accord',
#  'level',
#  'technology',
#  'method',
#  'produce',
#  'food',
#  'subdivisions',
#  'hunt',
#  'gather',
#  'pastoral',
#  'horticultural',
#  'agricultural',
#  'feudal',
#  'hunt',
#  'gather',
#  'main',
#  'form',
#  'food',
#  'production',
#  'societies',
#  'daily',
#  'collection',
#  'wild',
#  'plant',
#  'hunt',
#  'wild',
#  'animals',
#  'hunter',
#  'gatherers',
#  'constantly',
#  'search',
#  'food',
#  'result',
#  'build',
#  'permanent',
#  'villages',
#  'create',
#  'wide',
#  'variety',
#  'artifacts',
#  'usually',
#  'form',
#  'small',
#  'group',
#  'band',
#  'tribes',
#  'hunt',
#  'gather',
#  'societies',
#  'areas',
#  'abundant',
#  'resources',
#  'people',
#  'tlingit',
#  'live',
#  'larger',
#  'group',
#  'form',
#  'complex',
#  'hierarchical',
#  'social',
#  'structure',
#  'chiefdom',
#  'need',
#  'mobility',
#  'limit',
#  'size',
#  'societies',
#  'generally',
#  'consist',
#  'fewer',
#  'people',
#  'rarely',
#  'exceed',
#  'statuses',
#  'tribe',
#  'relatively',
#  'equal',
#  'decisions',
#  'reach',
#  'general',
#  'agreement',
#  'tie',
#  'bind',
#  'tribe',
#  'complex',
#  'band',
#  'leadership',
#  'personal',
#  'charismatic',
#  'special',
#  'purpose',
#  'tribal',
#  'society',
#  'political',
#  'offices',
#  'contain',
#  'real',
#  'power',
#  'chief',
#  'merely',
#  'person',
#  'influence',
#  'sort',
#  'adviser',
#  'tribal',
#  'consolidations',
#  'collective',
#  'action',
#  'governmental',
#  'family',
#  'form',
#  'main',
#  'social',
#  'unit',
#  'members',
#  'relate',
#  'birth',
#  'marriage',
#  'type',
#  'organization',
#  'require',
#  'family',
#  'carry',
#  'social',
#  'function',
#  'include',
#  'production',
#  'education',
#  'pastoral',
#  'pastoralism',
#  'slightly',
#  'efficient',
#  'form',
#  'subsistence',
#  'search',
#  'food',
#  'daily',
#  'basis',
#  'members',
#  'pastoral',
#  'society',
#  'rely',
#  'domesticate',
#  'herd',
#  'animals',
#  'meet',
#  'food',
#  'need',
#  'pastoralists',
#  'live',
#  'nomadic',
#  'life',
#  'move',
#  'herd',
#  'pasture',
#  'food',
#  'supply',
#  'reliable',
#  'pastoral',
#  'societies',
#  'support',
#  'larger',
#  'populations',
#  'food',
#  'surpluses',
#  'fewer',
#  'people',
#  'need',
#  'produce',
#  'food',
#  'result',
#  'division',
#  'labor',
#  'specialization',
#  'individuals',
#  'group',
#  'performance',
#  'specific',
#  'economic',
#  'activities',
#  'complex',
#  'example',
#  'people',
#  'craftworkers',
#  'produce',
#  'tool',
#  'weapons',
#  'jewelry',
#  'production',
#  'goods',
#  'encourage',
#  'trade',
#  'trade',
#  'help',
#  'create',
#  'inequality',
#  'families',
#  'acquire',
#  'goods',
#  'families',
#  'gain',
#  'power',
#  'increase',
#  'wealth',
#  'pass',
#  'property',
#  'generation',
#  'help',
#  'centralize',
#  'wealth',
#  'power',
#  'time',
#  'emerge',
#  'hereditary',
#  'chieftainships',
#  'typical',
#  'form',
#  'government',
#  'pastoral',
#  'societies',
#  'horticultural',
#  'fruit',
#  'vegetables',
#  'grow',
#  'garden',
#  'plot',
#  'clear',
#  'jungle',
#  'forest',
#  'provide',
#  'main',
#  'source',
#  'food',
#  'horticultural',
#  'society',
#  'societies',
#  'level',
#  'technology',
#  'complexity',
#  'similar',
#  'pastoral',
#  'societies',
#  'horticultural',
#  'group',
#  'slash',
#  'burn',
#  'method',
#  'raise',
#  'crop',
#  'wild',
#  'vegetation',
#  'burn',
#  'ash',
#  'fertilizers',
#  'horticulturists',
#  'human',
#  'labor',
#  'simple',
#  'tool',
#  'cultivate',
#  'land',
#  'season',
#  'land',
#  'barren',
#  'horticulturists',
#  'clear',
#  'plot',
#  'leave',
#  'plot',
#  'revert',
#  'natural',
#  'state',
#  'return',
#  'original',
#  'land',
#  'years',
#  'later',
#  'begin',
#  'process',
#  'rotate',
#  'garden',
#  'plot',
#  'horticulturists',
#  'stay',
#  'area',
#  'fairly',
#  'long',
#  'period',
#  'time',
#  'allow',
#  'build',
#  'semipermanent',
#  'permanent',
#  'villages',
#  'size',
#  'village',
#  'population',
#  'depend',
#  'land',
#  'available',
#  'farm',
#  'villages',
#  'range',
#  'people',
#  'pastoral',
#  'societies',
#  'surplus',
#  'food',
#  'lead',
#  'complex',
#  'division',
#  'labor',
#  'specialize',
#  'roles',
#  'horticultural',
#  'societies',
#  'include',
#  'craftspeople',
#  'shamans',
#  'religious',
#  'leaders',
#  'traders',
#  'role',
#  'specialization',
#  'allow',
#  'people',
#  'create',
#  'wide',
#  'variety',
#  'artifacts',
#  'pastoral',
#  'societies',
#  'surplus',
#  'food',
#  'lead',
#  'inequalities',
#  'wealth',
#  'power',
#  'horticultural',
#  'political',
#  'systems',
#  'develop',
#  'settle',
#  'nature',
#  'horticultural',
#  'life',
#  'agrarian',
#  'agrarian',
#  'societies',
#  'agricultural',
#  'technological',
#  'advance',
#  'cultivate',
#  'crop',
#  'large',
#  'area',
#  'sociologists',
#  'phrase',
#  'agricultural',
#  'revolution',
#  'refer',
#  'technological',
#  'change',
#  'occur',
#  'long',
#  'years',
#  'cultivate',
#  'crop',
#  ...]

# %%
#performance evaluation for BOW
for index, score in sorted(lda_model[bow_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.5150673389434814
# Topic: 0.007*"social" + 0.006*"study" + 0.005*"theory" + 0.005*"science" + 0.004*"human" + 0.004*"philosophy" + 0.004*"research" + 0.004*"self" + 0.003*"society" + 0.003*"university"
#
# Score: 0.3230469226837158
# Topic: 0.004*"government" + 0.004*"unite" + 0.004*"century" + 0.004*"world" + 0.004*"people" + 0.003*"city" + 0.003*"economic" + 0.003*"south" + 0.003*"empire" + 0.003*"force"
#
# Score: 0.07118179649114609
# Topic: 0.009*"university" + 0.007*"program" + 0.007*"engineer" + 0.006*"school" + 0.006*"technology" + 0.006*"science" + 0.005*"education" + 0.005*"college" + 0.005*"research" + 0.004*"institute"
#
# Score: 0.06176217272877693
# Topic: 0.009*"food" + 0.007*"company" + 0.005*"market" + 0.004*"drink" + 0.004*"finance" + 0.004*"service" + 0.003*"unite" + 0.003*"world" + 0.003*"financial" + 0.003*"bank"
#
# Score: 0.02862800471484661
# Topic: 0.007*"self" + 0.007*"music" + 0.006*"people" + 0.006*"culture" + 0.005*"health" + 0.004*"psychology" + 0.004*"group" + 0.003*"study" + 0.003*"social" + 0.003*"form"

# %%
#performance evaluation for TFIDF
for index, score in sorted(lda_model_tfidf[bow_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.756618857383728
# Topic: 0.002*"self" + 0.002*"social" + 0.002*"behavior" + 0.002*"theory" + 0.002*"psychology" + 0.002*"economics" + 0.002*"displaystyle" + 0.001*"model" + 0.001*"market" + 0.001*"study"
#
# Score: 0.1328658163547516
# Topic: 0.002*"food" + 0.002*"university" + 0.002*"engineer" + 0.002*"science" + 0.002*"literature" + 0.002*"sciences" + 0.001*"anthropology" + 0.001*"economics" + 0.001*"technology" + 0.001*"ministry"
#
# Score: 0.11007410287857056
# Topic: 0.002*"museum" + 0.002*"cities" + 0.002*"century" + 0.002*"city" + 0.001*"ancient" + 0.001*"anthropology" + 0.001*"university" + 0.001*"culture" + 0.001*"population" + 0.001*"south"

# %%
unseen_document = 'How a Pentagon deal became an identity crisis for Google'
bow_vector = dictionary.doc2bow(preprocess(unseen_document))
for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.8498205542564392	 Topic: 0.014*"music" + 0.006*"displaystyle" + 0.005*"number" + 0.004*"record" + 0.003*"group"
# Score: 0.016689682379364967	 Topic: 0.004*"government" + 0.004*"unite" + 0.004*"century" + 0.004*"world" + 0.004*"people"
# Score: 0.01668865606188774	 Topic: 0.007*"self" + 0.007*"music" + 0.006*"people" + 0.006*"culture" + 0.005*"health"
# Score: 0.01668822579085827	 Topic: 0.009*"food" + 0.007*"company" + 0.005*"market" + 0.004*"drink" + 0.004*"finance"
# Score: 0.01668785884976387	 Topic: 0.007*"social" + 0.006*"study" + 0.005*"theory" + 0.005*"science" + 0.004*"human"
# Score: 0.016685713082551956	 Topic: 0.006*"film" + 0.006*"series" + 0.005*"star" + 0.004*"american" + 0.004*"television"
# Score: 0.016685357317328453	 Topic: 0.008*"century" + 0.007*"literature" + 0.006*"write" + 0.004*"book" + 0.004*"bear"
# Score: 0.01668495684862137	 Topic: 0.019*"language" + 0.017*"film" + 0.007*"languages" + 0.005*"write" + 0.005*"word"
# Score: 0.01668478734791279	 Topic: 0.008*"road" + 0.007*"county" + 0.007*"city" + 0.005*"highway" + 0.005*"north"
# Score: 0.016684217378497124	 Topic: 0.009*"university" + 0.007*"program" + 0.007*"engineer" + 0.006*"school" + 0.006*"technology"
